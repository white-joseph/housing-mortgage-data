# %%
from pyprojroot.here import here
import pandas as pd

enterprise_df = pd.read_csv(here("data/raw/uad/enterprise_uad.csv"))
fha_df = pd.read_csv(here("data/raw/uad/fha_uad.csv"))

for col in enterprise_df.columns:
    print(col)
# Out:
# record_id
# year
# weight
# state_fips_2010
# state_fips_2020
# county_fips_2010
# county_fips_2020
# tract_fips_2010
# tract_fips_2020
# purpose
# owner_occupied
# contract_price
# built_up
# growth_rate
# property_value_trend
# demand_supply
# marketing_time
# sales_range_high
# sales_range_low
# updated_last_15_years
# lot_size
# quality
# condition
# bathrooms
# bedrooms
# gross_living_area
# median_adjustment
# average_adjustment
# adjusted_price
# number_comparables
# same_tract_percent
# calculated_proximity
# reported_proximity
# value_sale_comparison
# value_cost
# value_income
# appraised_value
# appraisal_to_contract
# comparison_to_contract
# dts_rural

# %%
for col in fha_df.columns:
    print(col)
# Out:
# record_id
# year
# weight
# state_fips_2010
# state_fips_2020
# county_fips_2010
# county_fips_2020
# tract_fips_2010
# tract_fips_2020
# purpose
# owner_occupied
# contract_price
# built_up
# growth_rate
# property_value_trend
# demand_supply
# marketing_time
# sales_range_high
# sales_range_low
# updated_last_15_years
# lot_size
# quality
# condition
# bathrooms
# bedrooms
# gross_living_area
# median_adjustment
# average_adjustment
# adjusted_price
# number_comparables
# same_tract_percent
# calculated_proximity
# reported_proximity
# value_sale_comparison
# value_cost
# value_income
# appraised_value
# appraisal_to_contract
# comparison_to_contract

# %%
enterprise_df.info()
fha_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481868 entries, 0 to 1481867
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   record_id               1481868 non-null  int64
#  1   year                    1481868 non-null  int64
#  2   weight                  1481868 non-null  int64
#  3   state_fips_2010         1377644 non-null  float64
#  4   state_fips_2020         104224 non-null   float64
#  5   county_fips_2010        1376686 non-null  float64
#  6   county_fips_2020        104207 non-null   float64
#  7   tract_fips_2010         1357804 non-null  float64
#  8   tract_fips_2020         102742 non-null   float64
#  9   purpose                 1481868 non-null  int64
#  10  owner_occupied          1481868 non-null  int64
#  11  contract_price          746237 non-null   float64
#  12  built_up                1481868 non-null  int64
# ...

# %%
enterprise_summary_df = pd.DataFrame({
    'Total Rows': len(enterprise_df),
    'Count of NaN': enterprise_df.isna().sum()
})

print(enterprise_summary_df)
# Out:
#                         Total Rows  Count of NaN
# record_id                  1481868             0
# year                       1481868             0
# weight                     1481868             0
# state_fips_2010            1481868        104224
# state_fips_2020            1481868       1377644
# county_fips_2010           1481868        105182
# county_fips_2020           1481868       1377661
# tract_fips_2010            1481868        124064
# tract_fips_2020            1481868       1379126
# purpose                    1481868             0
# owner_occupied             1481868             0
# contract_price             1481868        735631
# built_up                   1481868             0
# growth_rate                1481868             0
# property_value_trend       1481868             0
# demand_supply              1481868             0
# marketing_time             1481868             0
# sales_range_high           1481868        127806
# ...

# %%
fha_summary_df = pd.DataFrame({
    "Total Rows": len(fha_df),
    "Count of NaN": fha_df.isna().sum()
})

print(fha_summary_df)
# Out:
#                         Total Rows  Count of NaN
# record_id                   266474             0
# year                        266474             0
# weight                      266474             0
# state_fips_2010             266474         37089
# state_fips_2020             266474        229385
# county_fips_2010            266474         37487
# county_fips_2020            266474        229454
# tract_fips_2010             266474         76873
# tract_fips_2020             266474        238833
# purpose                     266474             0
# owner_occupied              266474             0
# contract_price              266474         56825
# built_up                    266474             0
# growth_rate                 266474             0
# property_value_trend        266474             0
# demand_supply               266474             0
# marketing_time              266474             0
# sales_range_high            266474         31730
# ...
